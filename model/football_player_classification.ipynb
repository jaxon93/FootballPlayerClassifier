# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/messi3.jpg')
img.shape
# Out:
# (2881, 2218, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2881, 2218)

# %%
gray
# Out:
# array([[130, 132, 133, ..., 125, 121, 125],
#        [132, 133, 133, ..., 123, 123, 126],
#        [129, 130, 130, ..., 122, 123, 126],
#        ...,
#        [117, 115, 113, ..., 211, 210, 210],
#        [117, 116, 115, ..., 211, 209, 209],
#        [120, 120, 121, ..., 210, 210, 210]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 384,  562, 1684, 1684]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (384, 562, 1684, 1684)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1684, 1684, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print("Error loading image:", image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/messi3.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/messi3.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/messi3.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/messi3.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 79,  87,  87],
#         [ 82,  92,  92],
#         [ 83,  93,  93],
#         ...,
#         [124, 109, 136],
#         [124, 109, 136],
#         [124, 109, 136]],
#
#        [[ 78,  88,  88],
#         [ 79,  89,  89],
#         [ 81,  91,  91],
#         ...,
#         [122, 107, 134],
#         [122, 107, 134],
#         [123, 108, 135]],
#
#        [[ 76,  86,  86],
#         [ 71,  83,  83],
#         [ 70,  80,  80],
#         ...,
#         [121, 107, 131],
#         [122, 108, 132],
#         [122, 108, 132]],
#
#        ...,
#
#        [[150, 158, 175],
#         [150, 158, 175],
#         [150, 158, 175],
#         ...,
#         [186, 183, 179],
#         [186, 183, 179],
#         [186, 183, 179]],
#
#        [[149, 156, 175],
#         [149, 156, 175],
#         [149, 156, 175],
#         ...,
#         [185, 184, 180],
#         [184, 183, 179],
#         [184, 183, 179]],
#
#        [[146, 153, 172],
#         [146, 153, 172],
#         [147, 154, 173],
#         ...,
#         [185, 184, 180],
#         [184, 183, 179],
#         [184, 183, 179]]], dtype=uint8)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cristiano_ronaldo',
#  './dataset/karim_benzema',
#  './dataset/lionel_messi',
#  './dataset/neymar_jr',
#  './dataset/robert_lewandowski']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/cristiano_ronaldo
# Generating cropped images in folder:  ./dataset/cropped/karim_benzema
# Generating cropped images in folder:  ./dataset/cropped/lionel_messi
# Generating cropped images in folder:  ./dataset/cropped/neymar_jr
# Generating cropped images in folder:  ./dataset/cropped/robert_lewandowski

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'cristiano_ronaldo': ['./dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo14.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo15.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo16.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo2.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo21.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo23.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo24.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo26.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo27.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo28.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo32.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo39.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo43.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo45.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo46.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo48.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo5.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo56.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo57.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo58.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo59.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo6.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo60.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo62.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo63.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo7.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo8.png',
#   './dataset/cropped/cristiano_ronaldo\\cristiano_ronaldo9.png'],
#  'karim_benzema': ['./dataset/cropped/karim_benzema\\karim_benzema1.png',
#   './dataset/cropped/karim_benzema\\karim_benzema10.png',
#   './dataset/cropped/karim_benzema\\karim_benzema11.png',
#   './dataset/cropped/karim_benzema\\karim_benzema12.png',
#   './dataset/cropped/karim_benzema\\karim_benzema13.png',
#   './dataset/cropped/karim_benzema\\karim_benzema14.png',
#   './dataset/cropped/karim_benzema\\karim_benzema15.png',
#   './dataset/cropped/karim_benzema\\karim_benzema17.png',
#   './dataset/cropped/karim_benzema\\karim_benzema18.png',
#   './dataset/cropped/karim_benzema\\karim_benzema19.png',
#   './dataset/cropped/karim_benzema\\karim_benzema2.png',
#   './dataset/cropped/karim_benzema\\karim_benzema20.png',
#   './dataset/cropped/karim_benzema\\karim_benzema21.png',
#   './dataset/cropped/karim_benzema\\karim_benzema23.png',
#   './dataset/cropped/karim_benzema\\karim_benzema24.png',
#   './dataset/cropped/karim_benzema\\karim_benzema25.png',
#   './dataset/cropped/karim_benzema\\karim_benzema28.png',
#   './dataset/cropped/karim_benzema\\karim_benzema29.png',
#   './dataset/cropped/karim_benzema\\karim_benzema3.png',
#   './dataset/cropped/karim_benzema\\karim_benzema31.png',
#   './dataset/cropped/karim_benzema\\karim_benzema32.png',
#   './dataset/cropped/karim_benzema\\karim_benzema33.png',
#   './dataset/cropped/karim_benzema\\karim_benzema34.png',
#   './dataset/cropped/karim_benzema\\karim_benzema35.png',
#   './dataset/cropped/karim_benzema\\karim_benzema5.png',
#   './dataset/cropped/karim_benzema\\karim_benzema7.png',
#   './dataset/cropped/karim_benzema\\karim_benzema8.png'],
#  'lionel_messi': ['./dataset/cropped/lionel_messi\\lionel_messi1.png',
#   './dataset/cropped/lionel_messi\\lionel_messi10.png',
#   './dataset/cropped/lionel_messi\\lionel_messi11.png',
#   './dataset/cropped/lionel_messi\\lionel_messi13.png',
#   './dataset/cropped/lionel_messi\\lionel_messi14.png',
#   './dataset/cropped/lionel_messi\\lionel_messi15.png',
#   './dataset/cropped/lionel_messi\\lionel_messi16.png',
#   './dataset/cropped/lionel_messi\\lionel_messi17.png',
#   './dataset/cropped/lionel_messi\\lionel_messi18.png',
#   './dataset/cropped/lionel_messi\\lionel_messi19.png',
#   './dataset/cropped/lionel_messi\\lionel_messi2.png',
#   './dataset/cropped/lionel_messi\\lionel_messi20.png',
#   './dataset/cropped/lionel_messi\\lionel_messi22.png',
#   './dataset/cropped/lionel_messi\\lionel_messi23.png',
#   './dataset/cropped/lionel_messi\\lionel_messi24.png',
#   './dataset/cropped/lionel_messi\\lionel_messi25.png',
#   './dataset/cropped/lionel_messi\\lionel_messi26.png',
#   './dataset/cropped/lionel_messi\\lionel_messi27.png',
#   './dataset/cropped/lionel_messi\\lionel_messi28.png',
#   './dataset/cropped/lionel_messi\\lionel_messi29.png',
#   './dataset/cropped/lionel_messi\\lionel_messi3.png',
#   './dataset/cropped/lionel_messi\\lionel_messi30.png',
#   './dataset/cropped/lionel_messi\\lionel_messi32.png',
#   './dataset/cropped/lionel_messi\\lionel_messi33.png',
#   './dataset/cropped/lionel_messi\\lionel_messi34.png',
#   './dataset/cropped/lionel_messi\\lionel_messi35.png',
#   './dataset/cropped/lionel_messi\\lionel_messi36.png',
#   './dataset/cropped/lionel_messi\\lionel_messi37.png',
#   './dataset/cropped/lionel_messi\\lionel_messi38.png',
#   './dataset/cropped/lionel_messi\\lionel_messi39.png',
#   './dataset/cropped/lionel_messi\\lionel_messi4.png',
#   './dataset/cropped/lionel_messi\\lionel_messi5.png',
#   './dataset/cropped/lionel_messi\\lionel_messi6.png',
#   './dataset/cropped/lionel_messi\\lionel_messi7.png',
#   './dataset/cropped/lionel_messi\\lionel_messi8.png',
#   './dataset/cropped/lionel_messi\\lionel_messi9.png'],
#  'neymar_jr': ['./dataset/cropped/neymar_jr\\neymar_jr15.png',
#   './dataset/cropped/neymar_jr\\neymar_jr16.png',
#   './dataset/cropped/neymar_jr\\neymar_jr17.png',
#   './dataset/cropped/neymar_jr\\neymar_jr2.png',
#   './dataset/cropped/neymar_jr\\neymar_jr20.png',
#   './dataset/cropped/neymar_jr\\neymar_jr22.png',
#   './dataset/cropped/neymar_jr\\neymar_jr25.png',
#   './dataset/cropped/neymar_jr\\neymar_jr28.png',
#   './dataset/cropped/neymar_jr\\neymar_jr29.png',
#   './dataset/cropped/neymar_jr\\neymar_jr3.png',
#   './dataset/cropped/neymar_jr\\neymar_jr31.png',
#   './dataset/cropped/neymar_jr\\neymar_jr32.png',
#   './dataset/cropped/neymar_jr\\neymar_jr34.png',
#   './dataset/cropped/neymar_jr\\neymar_jr37.png',
#   './dataset/cropped/neymar_jr\\neymar_jr38.png',
#   './dataset/cropped/neymar_jr\\neymar_jr39.png',
#   './dataset/cropped/neymar_jr\\neymar_jr4.png',
#   './dataset/cropped/neymar_jr\\neymar_jr40.png',
#   './dataset/cropped/neymar_jr\\neymar_jr41.png',
#   './dataset/cropped/neymar_jr\\neymar_jr44.png',
#   './dataset/cropped/neymar_jr\\neymar_jr45.png',
#   './dataset/cropped/neymar_jr\\neymar_jr47.png',
#   './dataset/cropped/neymar_jr\\neymar_jr48.png',
#   './dataset/cropped/neymar_jr\\neymar_jr49.png',
#   './dataset/cropped/neymar_jr\\neymar_jr5.png',
#   './dataset/cropped/neymar_jr\\neymar_jr51.png',
#   './dataset/cropped/neymar_jr\\neymar_jr52.png',
#   './dataset/cropped/neymar_jr\\neymar_jr53.png',
#   './dataset/cropped/neymar_jr\\neymar_jr55.png',
#   './dataset/cropped/neymar_jr\\neymar_jr58.png',
#   './dataset/cropped/neymar_jr\\neymar_jr59.png',
#   './dataset/cropped/neymar_jr\\neymar_jr6.png',
#   './dataset/cropped/neymar_jr\\neymar_jr7.png',
#   './dataset/cropped/neymar_jr\\neymar_jr8.png',
#   './dataset/cropped/neymar_jr\\neymar_jr9.png'],
#  'robert_lewandowski': ['./dataset/cropped/robert_lewandowski\\robert_lewandowski11.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski13.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski14.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski15.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski16.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski19.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski22.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski28.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski3.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski36.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski39.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski40.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski41.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski42.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski43.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski48.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski49.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski5.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski51.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski52.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski54.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski57.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski6.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski60.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski65.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski67.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski69.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski70.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski71.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski73.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski8.png',
#   './dataset/cropped/robert_lewandowski\\robert_lewandowski9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'cristiano_ronaldo': 0,
#  'karim_benzema': 1,
#  'lionel_messi': 2,
#  'neymar_jr': 3,
#  'robert_lewandowski': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[178],
#        [187],
#        [201],
#        ...,
#        [  0],
#        [  0],
#        [  0]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (158, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.875

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.86      0.86      0.86         7
#            2       0.83      0.83      0.83         6
#            3       0.79      0.85      0.81        13
#            4       1.00      1.00      1.00         7
#
#     accuracy                           0.88        40
#    macro avg       0.90      0.88      0.89        40
# weighted avg       0.88      0.88      0.88        40

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.763406
# 1        random_forest    0.492754
# 2  logistic_regression    0.838768
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.95

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 7,  0,  0,  0,  0],
#        [ 0,  6,  0,  1,  0],
#        [ 0,  1,  5,  0,  0],
#        [ 0,  1,  1, 11,  0],
#        [ 0,  0,  0,  0,  7]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'cristiano_ronaldo': 0,
#  'karim_benzema': 1,
#  'lionel_messi': 2,
#  'neymar_jr': 3,
#  'robert_lewandowski': 4}

# %%
import pickle
with open('saved_model.pkl', 'wb') as f:
    pickle.dump(best_clf, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
